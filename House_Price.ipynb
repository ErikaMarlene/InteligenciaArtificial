# %%
#Instalación de Kaggle
# !pip install -q kaggle

# %%
#Bibliotecas
from google.colab import files
import pandas as pd
import numpy as np
import seaborn as sns
pd.set_option('display.max_rows',None)

# %%
#Archivo
files.upload()
# Out:
#      <input type="file" id="files-65b771d7-27dd-4315-92af-52a645eca8b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65b771d7-27dd-4315-92af-52a645eca8b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Configurar biblioteca de kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/kaggle.json #Colocamos el archivo en la carpeta

# !chmod ~/.kaggle/kaggle.json 600 #Permiso 600 (lectura y escritura)

# !kaggle datasets list #Nos da la lista de referencia de la base de datos, ya configuramos kaggle dentro de nuestra compu
# Out:
# chmod: invalid mode: ‘/root/.kaggle/kaggle.json’
# Try 'chmod --help' for more information.
# ...
# ref                                                                   title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# nelgiriyewithana/countries-of-the-world-2023                          Global Country Information Dataset 2023             23KB  2023-07-08 20:37:33          11253        449  1.0
# nelgiriyewithana/global-youtube-statistics-2023                       Global YouTube Statistics 2023                      60KB  2023-07-28 15:36:38           3382        131  1.0
# ...

# %%
#Example download a database
# !kaggle competitions download -c House-Prices-Advanced-Regression-Techniques
# Out:
# ...
#   0% 0.00/199k [00:00<?, ?B/s]
# 100% 199k/199k [00:00<00:00, 89.6MB/s]

# %%
#Unzip archive
# !unzip House-Prices-Advanced-Regression-Techniques.zip -d '/content/kaggledb'
# Out:
# Archive:  House-Prices-Advanced-Regression-Techniques.zip
#   inflating: /content/kaggledb/data_description.txt
#   inflating: /content/kaggledb/sample_submission.csv
#   inflating: /content/kaggledb/test.csv
#   inflating: /content/kaggledb/train.csv

# %%
#Load database
df = pd.read_csv("/content/kaggledb/train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#df.dtypes

# %%
df.shape
# Out:
# (1460, 81)

# %%
diccionario = pd.DataFrame({'Variables': df.columns, 'Tipo de variable': df.dtypes})

# %%
diccionario = diccionario.reset_index(drop=True)

# %%
diccionario.to_csv('Diccionario.csv')

# %% [markdown]
# Diccionario
#
# |     Variables    | Tipo de variable  |   Descripción   |
# |:----------------:|:-----------------:|:---------------:|
# |        Id        |       int64       |  Numérico entero|
# |    MSSubClass    |       int64       |  Numérico entero|
# |     MSZoning     |      object       |Categórica Nominal|
# |   LotFrontage    |     float64       |  Numérico flotante|
# |     LotArea      |       int64       |  Numérico entero|
# |      Street      |      object       |Categórica Nominal|
# |      Alley       |      object       |Categórica Nominal|
# |    LotShape      |      object       |Categórica Nominal|
# |   LandContour    |      object       |Categórica Nominal|
# |    Utilities     |      object       |Categórica Ordinal|
# |    LotConfig     |      object       |Categórica Nominal|
# |    LandSlope     |      object       |Categórica Ordinal|
# |   Neighborhood   |      object       |Categórica Nominal|
# |    Condition1    |      object       |Categórica Nominal|
# |    Condition2    |      object       |Categórica Nominal|
# |    BldgType      |      object       |Categórica Nominal|
# |   HouseStyle     |      object       |Categórica Nominal|
# |   OverallQual    |       int64       |  Numérico entero|
# |   OverallCond    |       int64       |  Numérico entero|
# |    YearBuilt     |       int64       |  Numérico entero|
# |  YearRemodAdd    |       int64       |  Numérico entero|
# |    RoofStyle     |      object       |Categórica Nominal|
# |     RoofMatl     |      object       |Categórica Nominal|
# |   Exterior1st    |      object       |Categórica Nominal|
# |   Exterior2nd    |      object       |Categórica Nominal|
# |   MasVnrType     |      object       |Categórica Nominal|
# |    MasVnrArea    |     float64       |  Numérico flotante|
# |    ExterQual     |      object       |Categórica Ordinal|
# |    ExterCond     |      object       |Categórica Ordinal|
# |   Foundation     |      object       |Categórica Nominal|
# |    BsmtQual      |      object       |Categórica Ordinal|
# |    BsmtCond      |      object       |Categórica Ordinal|
# |  BsmtExposure    |      object       |Categórica Ordinal|
# |  BsmtFinType1    |      object       |Categórica Ordinal|
# |   BsmtFinSF1     |       int64       |  Numérico entero|
# |  BsmtFinType2    |      object       |Categórica Ordinal|
# |   BsmtFinSF2     |       int64       |  Numérico entero|
# |    BsmtUnfSF     |       int64       |  Numérico entero|
# |  TotalBsmtSF     |       int64       |  Numérico entero|
# |     Heating      |      object       |Categórica Nominal|
# |    HeatingQC     |      object       |Categórica Ordinal|
# |    CentralAir    |      object       |Categórica Ordinal|
# |    Electrical    |      object       |Categórica Nominal|
# |    1stFlrSF      |       int64       |  Numérico entero|
# |    2ndFlrSF      |       int64       |  Numérico entero|
# |  LowQualFinSF    |       int64       |  Numérico entero|
# |   GrLivArea      |       int64       |  Numérico entero|
# |  BsmtFullBath    |       int64       |  Numérico entero|
# |  BsmtHalfBath    |       int64       |  Numérico entero|
# |    FullBath      |       int64       |  Numérico entero|
# |    HalfBath      |       int64       |  Numérico entero|
# | BedroomAbvGr     |       int64       |  Numérico entero|
# | KitchenAbvGr     |       int64       |  Numérico entero|
# |  KitchenQual     |      object       |Categórica Ordinal|
# |  TotRmsAbvGrd    |       int64       |  Numérico entero|
# |   Functional     |  Categórico ordinal| Categórico ordinal|
# |   Fireplaces     |       int64       |  Numérico entero|
# |   FireplaceQu    |      object       |Categórica Ordinal|
# |   GarageType     |Categórica Nominal |Categórica Nominal|
# |  GarageYrBlt     |     float64       |  Numérico flotante|
# |  GarageFinish    |     object        |Categórica Ordinal|
# |   GarageCars     |       int64       |  Numérico entero|
# |   GarageArea     |       int64       |  Numérico entero|
# |   GarageQual     |      object       |Categórica Ordinal|
# |   GarageCond     |      object       |Categórica Ordinal|
# |   PavedDrive     |Categorica Ordinal|Categorica Ordinal|
# |   WoodDeckSF     |       int64       |  Numérico entero|
# |  OpenPorchSF     |       int64       |  Numérico entero|
# | EnclosedPorch    |       int64       |  Numérico entero|
# |    3SsnPorch     |       int64       |  Numérico entero|
# |   ScreenPorch    |       int64       |  Numérico entero|
# |    PoolArea      |       int64       |  Numérico entero|
# |     PoolQC       |      object       |Categórica Ordinal|
# |      Fence       |Categorica Ordinal|Categorica Ordinal|
# |   MiscFeature    |Categórica Nominal |Categórica Nominal|
# |    MiscVal       |       int64       |  Numérico entero|
# |     MoSold       |       int64       |  Numérico entero|
# |     YrSold       |       int64       |  Numérico entero|
# |    SaleType      |Categórica Nominal |Categórica Nominal|
# | SaleCondition    |Categórica Nominal |Categórica Nominal|
# |    SalePrice     |       int64       |  Num
